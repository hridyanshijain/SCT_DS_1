# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('API_SP.POP.TOTL.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    265 non-null    object
#  1   Country Code    265 non-null    object
#  2   Indicator Name  265 non-null    object
#  3   Indicator Code  265 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.drop(['Indicator Name' , 'Indicator Code' , 'Country Code'], axis=1,inplace=True)

# %%
df
# Out:
#                     Country Name         1960         1961         1962  \
# 0                          Aruba      54922.0      55578.0      56320.0
# 1    Africa Eastern and Southern  130075728.0  133534923.0  137171659.0
# 2                    Afghanistan    9035043.0    9214083.0    9404406.0
# 3     Africa Western and Central   97630925.0   99706674.0  101854756.0
# 4                         Angola    5231654.0    5301583.0    5354310.0
# ..                           ...          ...          ...          ...
# 260                       Kosovo     984846.0    1011421.0    1036950.0
# 261                  Yemen, Rep.    5532301.0    5655232.0    5782221.0
# 262                 South Africa   16440172.0   16908035.0   17418522.0
# 263                       Zambia    3153729.0    3254086.0    3358099.0
# 264                     Zimbabwe    3809389.0    3930401.0    4055959.0
#
#             1963         1964         1965         1966         1967  \
# ...

# %%
#India Data 

india_data = df.loc[df['Country Name']=="India"].T
india_data = india_data.reset_index()
india_data.columns = ['Year', 'Population']
india_data = india_data[1:]
india_data['Year'] = india_data['Year'].astype(int)
india_data['Population'] = india_data['Population'].astype(float)

india_data.isna().sum()
india_data
# Out:
#     Year    Population
# 1   1960  4.359903e+08
# 2   1961  4.465647e+08
# 3   1962  4.572831e+08
# 4   1963  4.681386e+08
# 5   1964  4.792296e+08
# ..   ...           ...
# 61  2020  1.402618e+09
# 62  2021  1.414204e+09
# 63  2022  1.425423e+09
# 64  2023  1.438070e+09
# 65  2024  1.450936e+09
#
# [65 rows x 2 columns]

# %%
# 📊 Bar Chart - Population Over Time

plt.figure(figsize=(12,6))
plt.bar(india_data['Year'], india_data['Population']/1e9, color="Pink")
plt.title("India's Population Over Time", fontsize=16)
plt.xlabel("Year")
plt.ylabel("Population (Billions)")
plt.show()

# %%
# 📊 Histogram - Distribution of Population Values
plt.figure(figsize=(10,6))
sns.histplot(india_data['Population']/1e9, bins=10, color="red", edgecolor="red", kde=True)
plt.title("Distribution of India's Population", fontsize=16)
plt.xlabel("Population (Billions)")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\rahul\OneDrive\Desktop\h.python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
grp = df.groupby('Country Name')
country_list=[]
for group, data in grp:
    # print(group)
    country_list.append(group)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def show():
    for i in country_list:
        data = df.loc[df['Country Name']==i].T
        data = data.reset_index()
        data.columns = ['Year', 'Population']
        data = data[1:]
        data['Year'] = data['Year'].astype(int)
        data['Population'] = data['Population'].astype(float)
        
        # Clean NaN
        data = data.dropna()

        # 📊 Bar Chart
        print("📊 Bar Chart - Population Over Time")
        plt.figure(figsize=(12,6))
        plt.bar(data['Year'], data['Population']/1e9, color="skyblue")
        plt.title(f"{i} Population Over Time", fontsize=16)
        plt.xlabel("Year")
        plt.ylabel("Population (Billions)")
        plt.show()

        print('\n\n')

        # 📊 Histogram with KDE
        print('📊 Histogram - Distribution of Population Values')
        plt.figure(figsize=(10,6))
        sns.histplot(data['Population']/1e9, bins=10, color="orange", edgecolor="black", kde=True)
        plt.title(f"Distribution of {i} Population", fontsize=16)
        plt.xlabel("Population (Billions)")
        plt.ylabel("Frequency")
        plt.show()

show()
# Out:
# 📊 Bar Chart - Population Over Time
# 📊 Histogram - Distribution of Population Values
# C:\Users\rahul\OneDrive\Desktop\h.python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 📊 Bar Chart - Population Over Time
# 📊 Histogram - Distribution of Population Values
# C:\Users\rahul\OneDrive\Desktop\h.python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 📊 Bar Chart - Population Over Time
# 📊 Histogram - Distribution of Population Values
# ...
